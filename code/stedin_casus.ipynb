# %% [markdown]
# # Stedin casus
# # Tristan Looden 02-03-2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from xgboost import XGBRegressor, XGBClassifier, plot_importance
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, mean_absolute_error, mean_squared_error
import datetime


sns.set_style('white')

# %%
df =  pd.read_pickle('Case_Dataset.pkl')

# %%
# Choose forecasting domain
forecast_horizons = range(1,96)

# %% [markdown]
# ## descriptives

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90122 entries, 2021-04-02 10:15:00+00:00 to 2023-11-05 23:00:00+00:00
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transformer_load  90122 non-null  float64
#  1   radiation         90119 non-null  float64
#  2   windspeed_10m     90119 non-null  float64
#  3   windspeed_100m    90119 non-null  float64
#  4   windspeed_squall  90119 non-null  float64
#  5   nedu_e1a          90122 non-null  float64
#  6   nedu_e1b          90122 non-null  float64
#  7   nedu_e1c          90122 non-null  float64
#  8   nedu_e2a          90122 non-null  float64
#  9   nedu_e2b          90122 non-null  float64
#  10  nedu_e3a          90122 non-null  float64
#  11  nedu_e3b          90122 non-null  float64
#  12  nedu_e3c          90122 non-null  float64
#  13  nedu_e3d          90122 non-null  float64
#  14  nedu_e4a          90122 non-null  float64
# dtypes: float64(15)
# memory usage: 11.0 MB

# %%
df.head()
# Out:
#                            transformer_load  radiation  windspeed_10m  \
# 2021-04-02 10:15:00+00:00          0.314834  2362538.0       7.087363
# 2021-04-02 10:30:00+00:00          0.455148  2395208.0       7.169058
# 2021-04-02 10:45:00+00:00          0.492845  2427878.0       7.250822
# 2021-04-02 11:00:00+00:00          0.479581  2460548.0       7.332652
# 2021-04-02 11:15:00+00:00          0.512740  2471373.5       7.532573
#
#                            windspeed_100m  windspeed_squall  nedu_e1a  \
# 2021-04-02 10:15:00+00:00        8.304909         11.329289  0.000023
# 2021-04-02 10:30:00+00:00        8.406696         11.468938  0.000022
# 2021-04-02 10:45:00+00:00        8.508593         11.608627  0.000022
# 2021-04-02 11:00:00+00:00        8.610595         11.748355  0.000021
# 2021-04-02 11:15:00+00:00        8.868861         12.003352  0.000020
#
#                            nedu_e1b  nedu_e1c  nedu_e2a  nedu_e2b  nedu_e3a  \
# 2021-04-02 10:15:00+00:00  0.000017  0.000013  0.000029  0.000025  0.000045
# 2021-04-02 10:30:00+00:00  0.000016  0.000012  0.000029  0.000024  0.000044
# 2021-04-02 10:45:00+00:00  0.000015  0.000011  0.000028  0.000024  0.000043
# 2021-04-02 11:00:00+00:00  0.000014  0.000010  0.000028  0.000024  0.000043
# 2021-04-02 11:15:00+00:00  0.000013  0.000010  0.000028  0.000024  0.000043
#
#                            nedu_e3b  nedu_e3c  nedu_e3d  nedu_e4a
# 2021-04-02 10:15:00+00:00  0.000045  0.000045  0.000045       0.0
# 2021-04-02 10:30:00+00:00  0.000044  0.000044  0.000044       0.0
# 2021-04-02 10:45:00+00:00  0.000043  0.000043  0.000043       0.0
# 2021-04-02 11:00:00+00:00  0.000043  0.000043  0.000043       0.0
# 2021-04-02 11:15:00+00:00  0.000043  0.000043  0.000043       0.0

# %%
df.describe()
# Out:
#        transformer_load     radiation  windspeed_10m  windspeed_100m  \
# count      90122.000000  9.011900e+04   90119.000000    90119.000000
# mean           0.415224  5.150861e+05       4.661820        7.355531
# std            0.207996  7.941373e+05       2.544169        3.454582
# min            0.000000 -2.720625e+02       0.009033        0.013995
# 25%            0.247469  5.450448e-11       2.792512        4.975678
# 50%            0.363002  3.963215e+04       4.296795        7.035952
# 75%            0.547644  7.837728e+05       6.035251        9.324676
# max            2.143106  3.197917e+06      20.362995       28.985344
#
#        windspeed_squall      nedu_e1a      nedu_e1b      nedu_e1c  \
# count      90119.000000  90122.000000  90122.000000  90122.000000
# mean           7.955567      0.000028      0.000027      0.000027
# std            4.168576      0.000009      0.000013      0.000014
# min            0.059771      0.000014      0.000000      0.000000
# 25%            4.912684      0.000020      0.000019      0.000019
# 50%            7.341977      0.000027      0.000025      0.000024
# 75%           10.149324      0.000034      0.000036      0.000037
# max           35.749813      0.000066      0.000076      0.000076
#
#            nedu_e2a      nedu_e2b      nedu_e3a      nedu_e3b      nedu_e3c  \
# count  90122.000000  90122.000000  90122.000000  90122.000000  90122.000000
# mean       0.000028      0.000028      0.000028      0.000028      0.000028
# std        0.000006      0.000007      0.000011      0.000011      0.000011
# min        0.000017      0.000009      0.000014      0.000014      0.000014
# 25%        0.000023      0.000023      0.000019      0.000019      0.000019
# 50%        0.000029      0.000027      0.000023      0.000023      0.000023
# 75%        0.000032      0.000032      0.000037      0.000037      0.000037
# max        0.000047      0.000049      0.000057      0.000057      0.000057
#
#            nedu_e3d      nedu_e4a
# count  90122.000000  90122.000000
# mean       0.000028      0.000027
# std        0.000011      0.000030
# min        0.000014      0.000000
# 25%        0.000019      0.000000
# 50%        0.000023      0.000000
# 75%        0.000037      0.000060
# max        0.000057      0.000060

# %%
df.corr()
# Out:
#                   transformer_load  radiation  windspeed_10m  windspeed_100m  \
# transformer_load          1.000000   0.310983       0.792002        0.688225
# radiation                 0.310983   1.000000       0.057008       -0.210221
# windspeed_10m             0.792002   0.057008       1.000000        0.919440
# windspeed_100m            0.688225  -0.210221       0.919440        1.000000
# windspeed_squall          0.803967   0.120948       0.974461        0.873585
# nedu_e1a                  0.014982  -0.110961       0.092785        0.111490
# nedu_e1b                 -0.173675  -0.521475       0.011275        0.162728
# nedu_e1c                 -0.200606  -0.565887      -0.009304        0.157133
# nedu_e2a                  0.070762   0.187554       0.134435        0.044515
# nedu_e2b                 -0.153446  -0.342838       0.046113        0.126395
# nedu_e3a                  0.184099   0.429468       0.170849        0.016650
# nedu_e3b                  0.184099   0.429468       0.170849        0.016650
# nedu_e3c                  0.184099   0.429468       0.170849        0.016650
# nedu_e3d                  0.184099   0.429468       0.170849        0.016650
# nedu_e4a                 -0.194562  -0.594928      -0.123603        0.128961
#
#                   windspeed_squall  nedu_e1a  nedu_e1b  nedu_e1c  nedu_e2a  \
# transformer_load          0.803967  0.014982 -0.173675 -0.200606  0.070762
# radiation                 0.120948 -0.110961 -0.521475 -0.565887  0.187554
# windspeed_10m             0.974461  0.092785  0.011275 -0.009304  0.134435
# windspeed_100m            0.873585  0.111490  0.162728  0.157133  0.044515
# windspeed_squall          1.000000  0.098651 -0.020261 -0.044009  0.162261
# nedu_e1a                  0.098651  1.000000  0.838706  0.805119  0.732509
# nedu_e1b                 -0.020261  0.838706  1.000000  0.990218  0.476755
# nedu_e1c                 -0.044009  0.805119  0.990218  1.000000  0.429652
# nedu_e2a                  0.162261  0.732509  0.476755  0.429652  1.000000
# nedu_e2b                  0.028282  0.725290  0.814651  0.798719  0.793583
# nedu_e3a                  0.200740  0.143220 -0.127456 -0.184958  0.695226
# nedu_e3b                  0.200740  0.143220 -0.127456 -0.184958  0.695226
# nedu_e3c                  0.200740  0.143220 -0.127456 -0.184958  0.695226
# nedu_e3d                  0.200740  0.143220 -0.127456 -0.184958  0.695226
# nedu_e4a                 -0.178628 -0.081961  0.263157  0.308712 -0.433444
#
#                   nedu_e2b  nedu_e3a  nedu_e3b  nedu_e3c  nedu_e3d  nedu_e4a
# transformer_load -0.153446  0.184099  0.184099  0.184099  0.184099 -0.194562
# radiation        -0.342838  0.429468  0.429468  0.429468  0.429468 -0.594928
# windspeed_10m     0.046113  0.170849  0.170849  0.170849  0.170849 -0.123603
# windspeed_100m    0.126395  0.016650  0.016650  0.016650  0.016650  0.128961
# windspeed_squall  0.028282  0.200740  0.200740  0.200740  0.200740 -0.178628
# nedu_e1a          0.725290  0.143220  0.143220  0.143220  0.143220 -0.081961
# nedu_e1b          0.814651 -0.127456 -0.127456 -0.127456 -0.127456  0.263157
# nedu_e1c          0.798719 -0.184958 -0.184958 -0.184958 -0.184958  0.308712
# nedu_e2a          0.793583  0.695226  0.695226  0.695226  0.695226 -0.433444
# nedu_e2b          1.000000  0.347136  0.347136  0.347136  0.347136 -0.006114
# nedu_e3a          0.347136  1.000000  1.000000  1.000000  1.000000 -0.538190
# nedu_e3b          0.347136  1.000000  1.000000  1.000000  1.000000 -0.538190
# nedu_e3c          0.347136  1.000000  1.000000  1.000000  1.000000 -0.538190
# nedu_e3d          0.347136  1.000000  1.000000  1.000000  1.000000 -0.538190
# nedu_e4a         -0.006114 -0.538190 -0.538190 -0.538190 -0.538190  1.000000

# %% [markdown]
# ## Basic QC
#
#
# Three consecutive missing values in weather columns -> linear interpolation
#
# Missing timestamps -> linear interpolation
#
# suspected outlier in transformer_load -> linear interpolation
#
# nedu_e3 columns are identical -> drop all but one

# %%
# check if index is sorted
is_sorted = df.index.is_monotonic_increasing
print(is_sorted)
# Out:
# True

# %%
df.isnull().sum()
# Out:
# transformer_load    0
# radiation           3
# windspeed_10m       3
# windspeed_100m      3
# windspeed_squall    3
# nedu_e1a            0
# nedu_e1b            0
# nedu_e1c            0
# nedu_e2a            0
# nedu_e2b            0
# nedu_e3a            0
# nedu_e3b            0
# nedu_e3c            0
# nedu_e3d            0
# nedu_e4a            0
# dtype: int64

# %%
# check nan
missing_rows = df[df.isnull().any(axis=1)]
print(missing_rows)
# Out:
#                            transformer_load  radiation  windspeed_10m  \
# 2023-10-22 05:15:00+00:00          0.559860        NaN            NaN
# 2023-10-22 05:30:00+00:00          0.619546        NaN            NaN
# 2023-10-22 05:45:00+00:00          0.631414        NaN            NaN
#
#                            windspeed_100m  windspeed_squall  nedu_e1a  \
# 2023-10-22 05:15:00+00:00             NaN               NaN  0.000018
# 2023-10-22 05:30:00+00:00             NaN               NaN  0.000019
# 2023-10-22 05:45:00+00:00             NaN               NaN  0.000020
#
#                            nedu_e1b  nedu_e1c  nedu_e2a  nedu_e2b  nedu_e3a  \
# 2023-10-22 05:15:00+00:00  0.000022  0.000022  0.000025  0.000028  0.000018
# 2023-10-22 05:30:00+00:00  0.000023  0.000024  0.000026  0.000029  0.000018
# 2023-10-22 05:45:00+00:00  0.000024  0.000025  0.000027  0.000030  0.000018
#
#                            nedu_e3b  nedu_e3c  nedu_e3d  nedu_e4a
# 2023-10-22 05:15:00+00:00  0.000018  0.000018  0.000018   0.00006
# 2023-10-22 05:30:00+00:00  0.000018  0.000018  0.000018   0.00006
# 2023-10-22 05:45:00+00:00  0.000018  0.000018  0.000018   0.00006

# %%
#check duplication
df.duplicated().sum()
# Out:
# 0

# %%
#find missing timestamps
freq = '15T'

# Generate full expected timestamp range
full_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq=freq)

# Find missing timestamps
missing_timestamps = full_range.difference(df.index)

print(missing_timestamps)
print(len(missing_timestamps))
# Out:
# DatetimeIndex(['2021-10-31 01:15:00+00:00', '2021-10-31 01:30:00+00:00',
#                '2021-10-31 01:45:00+00:00', '2021-12-14 17:45:00+00:00',
#                '2021-12-14 18:00:00+00:00', '2021-12-14 18:15:00+00:00',
#                '2021-12-14 18:30:00+00:00', '2021-12-14 18:45:00+00:00',
#                '2021-12-14 19:00:00+00:00', '2021-12-14 19:15:00+00:00',
#                ...
#                '2023-10-23 05:45:00+00:00', '2023-10-23 17:45:00+00:00',
#                '2023-10-24 01:45:00+00:00', '2023-10-24 05:45:00+00:00',
#                '2023-10-24 07:00:00+00:00', '2023-10-24 07:15:00+00:00',
#                '2023-10-29 01:15:00+00:00', '2023-10-29 01:30:00+00:00',
#                '2023-10-29 01:45:00+00:00', '2023-10-30 13:45:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=842, freq=None)
# 842

# %%
# enforce full data frequency
df = df.asfreq('15T')

# %%
# interpolate the various missing values identified above
df.interpolate(method='linear', inplace=True)

# %%
# plotting data distributions

# select num columns
num_cols = df.select_dtypes(include=['number']).columns

# define grid 
num_plots = len(num_cols)
cols = 5  
rows = math.ceil(num_plots / cols)  

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
axes = axes.flatten()

# loop through columns
for i, col in enumerate(num_cols):
    sns.boxplot(data=df, x=col, ax=axes[i])
    axes[i].set_title(f"Boxplot of {col}")
    
plt.tight_layout()
plt.show()
#plt.savefig('/Users/tristan/Desktop/stedin_casus/figs/data_boxplot.pdf')

# %%
# find the row with the transformer outlier, display some rows around it.

max_index = df['transformer_load'].idxmax() 
max_loc = df.index.get_loc(max_index) 

num_surrounding = 2
start = max(0, max_loc - num_surrounding)
end = min(len(df), max_loc + num_surrounding + 1)

surrounding_rows = df.iloc[start:end]
print(surrounding_rows)
# Out:
#                            transformer_load     radiation  windspeed_10m  \
# 2021-04-05 10:15:00+00:00          1.119023  2.323946e+06      11.772784
# 2021-04-05 10:30:00+00:00          1.182548  2.299042e+06      11.456744
# 2021-04-05 10:45:00+00:00          1.236998  2.274139e+06      11.140731
# 2021-04-05 11:00:00+00:00          1.060384  2.249235e+06      10.824746
# 2021-04-05 11:15:00+00:00          0.966841  2.213918e+06      10.985853
#
#                            windspeed_100m  windspeed_squall  nedu_e1a  \
# 2021-04-05 10:15:00+00:00       14.727335         18.913018  0.000030
# 2021-04-05 10:30:00+00:00       14.340160         18.803892  0.000029
# 2021-04-05 10:45:00+00:00       13.952988         18.698328  0.000030
# 2021-04-05 11:00:00+00:00       13.565821         18.596389  0.000029
# 2021-04-05 11:15:00+00:00       13.792987         18.417936  0.000029
#
#                            nedu_e1b  nedu_e1c  nedu_e2a  nedu_e2b  nedu_e3a  \
# 2021-04-05 10:15:00+00:00  0.000023  0.000020  0.000022  0.000017  0.000020
# 2021-04-05 10:30:00+00:00  0.000023  0.000019  0.000022  0.000017  0.000021
# 2021-04-05 10:45:00+00:00  0.000023  0.000019  0.000022  0.000017  0.000020
# 2021-04-05 11:00:00+00:00  0.000023  0.000018  0.000022  0.000016  0.000020
# 2021-04-05 11:15:00+00:00  0.000022  0.000017  0.000022  0.000016  0.000021
#
#                            nedu_e4a
# 2021-04-05 10:15:00+00:00       0.0
# 2021-04-05 10:30:00+00:00       0.0
# 2021-04-05 10:45:00+00:00       0.0
# 2021-04-05 11:00:00+00:00       0.0
# 2021-04-05 11:15:00+00:00       0.0

# %%
# linear interpolation for transformator outlier
col_name='transformer_load'
df.loc[max_index, col_name] = None
df[col_name] = df[col_name].interpolate(method='linear')

# %%
# drop duplicate nedu columns
drop_columns = ['nedu_e3b', 'nedu_e3c', 'nedu_e3d']  
df = df.drop(columns=drop_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/8d/tcfrvtjd05q1m1x6nc9qztbw0000gn/T/ipykernel_19119/4033168984.py in <module>
#       1 # drop duplicate nedu columns
#       2 drop_columns = ['nedu_e3b', 'nedu_e3c', 'nedu_e3d']
# ----> 3 df = df.drop(columns=drop_columns)
#
# ~/anaconda3/envs/science/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/anaconda3/envs/science/lib/python3.10/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5394                 weight  1.0     0.8
#    5395         """
# -> 5396         return super().drop(
#    5397             labels=labels,
#    5398             axis=axis,
#
# ~/anaconda3/envs/science/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/anaconda3/envs/science/lib/python3.10/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# ~/anaconda3/envs/science/lib/python3.10/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# ~/anaconda3/envs/science/lib/python3.10/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6975         if mask.any():
#    6976             if errors != "ignore":
# -> 6977                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978             indexer = indexer[~mask]
#    6979         return self.delete(indexer)
#
# KeyError: "['nedu_e3b', 'nedu_e3c', 'nedu_e3d'] not found in axis"

# %% [markdown]
# ## Feature engineering
#
# rate of change in load
#
# weekend
#
# day and year cycles
#
# lags
#
# ewmas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90964 entries, 2021-04-02 10:15:00+00:00 to 2023-11-05 23:00:00+00:00
# Freq: 15T
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transformer_load  90964 non-null  float64
#  1   radiation         90964 non-null  float64
#  2   windspeed_10m     90964 non-null  float64
#  3   windspeed_100m    90964 non-null  float64
#  4   windspeed_squall  90964 non-null  float64
#  5   nedu_e1a          90964 non-null  float64
#  6   nedu_e1b          90964 non-null  float64
#  7   nedu_e1c          90964 non-null  float64
#  8   nedu_e2a          90964 non-null  float64
#  9   nedu_e2b          90964 non-null  float64
#  10  nedu_e3a          90964 non-null  float64
#  11  nedu_e4a          90964 non-null  float64
# dtypes: float64(12)
# memory usage: 11.0 MB

# %%
df_aug = df.copy()

# rate of change in load
#df_aug['load_delta'] = df_aug['transformer_load'].diff()
#df_aug['load_ewma_4'] = df_aug['load_delta'].ewm(span=4, adjust=False).mean()

# weekend
#df_aug['is_weekend'] = (df_aug.index.dayofweek >= 5).astype(int) 

# fourier features for day-cycle and year-cycle
#df_aug['sin_day'] = np.sin(2 * np.pi * df_aug.index.hour / 24)
#df_aug['cos_day'] = np.cos(2 * np.pi * df_aug.index.hour / 24)
#df_aug['sin_year'] = np.sin(2 * np.pi * df_aug.index.dayofyear / 365)
#df_aug['cos_year'] = np.cos(2 * np.pi * df_aug.index.dayofyear / 365)

# features to use for lags/ewma
lag_features = ['transformer_load', 'radiation', 'windspeed_10m','windspeed_100m','windspeed_squall']
#['transformer_load', 'radiation', 'windspeed_10m','windspeed_100m','windspeed_squall','nedu_e1a','nedu_e1b', 'nedu_e1c','nedu_e2a','nedu_e2b','nedu_e3a','nedu_e4a']

"""
# lags
lags = [96]                
for f in lag_features:
    for l in lags:
        df_aug[f+'_lag_'+str(l)] = df_aug[f].shift(l)
"""
# EWMA
ewmas = [16, 192]                
for f in lag_features:
    for e in ewmas:
        df_aug[f+'_ewma_'+str(e)] = df_aug[f].ewm(span=e, adjust=False).mean()


# drop all nedu
drop_columns = ['nedu_e1a', 'nedu_e3a','nedu_e1b','nedu_e1c','nedu_e2a','nedu_e2b','nedu_e4a','windspeed_10m']  
df_aug = df_aug.drop(columns=drop_columns)

# %%
df_aug.corr()
# Out:
#                   transformer_load  radiation  windspeed_100m  \
# transformer_load          1.000000   0.311461        0.688889
# radiation                 0.311461   1.000000       -0.210303
# windspeed_100m            0.688889  -0.210303        1.000000
# windspeed_squall          0.805056   0.122396        0.873152
#
#                   windspeed_squall
# transformer_load          0.805056
# radiation                 0.122396
# windspeed_100m            0.873152
# windspeed_squall          1.000000

# %%
def create_supervised_data(df, horizon=1, binary=False):
    '''Create X, y datasets for given forecast horizon.'''

    data = df.copy()

    # shift target attached data
    #cols_to_shift = ['is_weekend', 'sin_day', 'cos_day', 'sin_year', 'cos_year']
    #data[cols_to_shift] = data[cols_to_shift].shift(-horizon)

    # shift target
    data['y_future'] = data['transformer_load'].shift(-horizon)

    # Drop nan rows
    data.dropna(inplace=True)

    X = data.drop(columns=['y_future'])  
    
    if binary == True:
        y = data['exceed'] = (data['y_future'] > 1).astype(int)
    else:
        y = data['y_future']
        
    return X, y

# %% [markdown]
# ## xgboost regression model training

# %%
models = {}
r2_scores = {}
rmse_scores = {}
mae_scores = {}

for horizon in forecast_horizons:
    # create supervised dataset for horizon
    X, y = create_supervised_data(df_aug, horizon=horizon)

    # split data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)  

    # train  model
    model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5)
    model.fit(X_train, y_train)
    
    # evaluate model
    score = model.score(X_test, y_test)
    r2_scores[horizon]=score

    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse_scores[horizon] = rmse
    mae = mean_absolute_error(y_test, y_pred)
    mae_scores[horizon] = mae

    print(f"Horizon={horizon}: R^2 = {score:.3f}")

    # save model
    models[horizon] = model
# Out:
# Horizon=1: R^2 = 0.971
# Horizon=2: R^2 = 0.932
# Horizon=3: R^2 = 0.898
# Horizon=4: R^2 = 0.865
# Horizon=5: R^2 = 0.832
# Horizon=6: R^2 = 0.797
# Horizon=7: R^2 = 0.760
# Horizon=8: R^2 = 0.723
# Horizon=9: R^2 = 0.684
# Horizon=10: R^2 = 0.646
# Horizon=11: R^2 = 0.610
# Horizon=12: R^2 = 0.573
# Horizon=13: R^2 = 0.539
# Horizon=14: R^2 = 0.505
# Horizon=15: R^2 = 0.470
# Horizon=16: R^2 = 0.440
# Horizon=17: R^2 = 0.410
# Horizon=18: R^2 = 0.383
# Horizon=19: R^2 = 0.357
# Horizon=20: R^2 = 0.334
# Horizon=21: R^2 = 0.313
# Horizon=22: R^2 = 0.290
# Horizon=23: R^2 = 0.272
# Horizon=24: R^2 = 0.258
# Horizon=25: R^2 = 0.239
# Horizon=26: R^2 = 0.230
# Horizon=27: R^2 = 0.221
# Horizon=28: R^2 = 0.217
# Horizon=29: R^2 = 0.209
# Horizon=30: R^2 = 0.205
# Horizon=31: R^2 = 0.204
# Horizon=32: R^2 = 0.204
# Horizon=33: R^2 = 0.205
# Horizon=34: R^2 = 0.204
# Horizon=35: R^2 = 0.207
# Horizon=36: R^2 = 0.210
# Horizon=37: R^2 = 0.211
# Horizon=38: R^2 = 0.213
# Horizon=39: R^2 = 0.218
# Horizon=40: R^2 = 0.223
# Horizon=41: R^2 = 0.227
# Horizon=42: R^2 = 0.229
# Horizon=43: R^2 = 0.234
# Horizon=44: R^2 = 0.240
# Horizon=45: R^2 = 0.244
# Horizon=46: R^2 = 0.251
# Horizon=47: R^2 = 0.253
# Horizon=48: R^2 = 0.254
# Horizon=49: R^2 = 0.257
# Horizon=50: R^2 = 0.258
# Horizon=51: R^2 = 0.261
# Horizon=52: R^2 = 0.258
# Horizon=53: R^2 = 0.257
# Horizon=54: R^2 = 0.253
# Horizon=55: R^2 = 0.245
# Horizon=56: R^2 = 0.237
# Horizon=57: R^2 = 0.230
# Horizon=58: R^2 = 0.221
# Horizon=59: R^2 = 0.208
# Horizon=60: R^2 = 0.196
# Horizon=61: R^2 = 0.188
# Horizon=62: R^2 = 0.181
# Horizon=63: R^2 = 0.170
# Horizon=64: R^2 = 0.159
# Horizon=65: R^2 = 0.151
# Horizon=66: R^2 = 0.143
# Horizon=67: R^2 = 0.135
# Horizon=68: R^2 = 0.126
# Horizon=69: R^2 = 0.120
# Horizon=70: R^2 = 0.115
# Horizon=71: R^2 = 0.110
# Horizon=72: R^2 = 0.107
# Horizon=73: R^2 = 0.107
# Horizon=74: R^2 = 0.107
# Horizon=75: R^2 = 0.110
# Horizon=76: R^2 = 0.114
# Horizon=77: R^2 = 0.116
# Horizon=78: R^2 = 0.122
# Horizon=79: R^2 = 0.132
# Horizon=80: R^2 = 0.139
# Horizon=81: R^2 = 0.148
# Horizon=82: R^2 = 0.158
# Horizon=83: R^2 = 0.170
# Horizon=84: R^2 = 0.181
# Horizon=85: R^2 = 0.193
# Horizon=86: R^2 = 0.204
# Horizon=87: R^2 = 0.216
# Horizon=88: R^2 = 0.226
# Horizon=89: R^2 = 0.236
# Horizon=90: R^2 = 0.245
# Horizon=91: R^2 = 0.257
# Horizon=92: R^2 = 0.265
# Horizon=93: R^2 = 0.272
# Horizon=94: R^2 = 0.277
# Horizon=95: R^2 = 0.276
# Horizon=96: R^2 = 0.276
# Horizon=97: R^2 = 0.275
# Horizon=98: R^2 = 0.270
# Horizon=99: R^2 = 0.264
# Horizon=100: R^2 = 0.255
# Horizon=101: R^2 = 0.246
# Horizon=102: R^2 = 0.234
# Horizon=103: R^2 = 0.222
# Horizon=104: R^2 = 0.205
# Horizon=105: R^2 = 0.188
# Horizon=106: R^2 = 0.174
# Horizon=107: R^2 = 0.160
# Horizon=108: R^2 = 0.144
# Horizon=109: R^2 = 0.131
# Horizon=110: R^2 = 0.117
# Horizon=111: R^2 = 0.103
# Horizon=112: R^2 = 0.088
# Horizon=113: R^2 = 0.078
# Horizon=114: R^2 = 0.066
# Horizon=115: R^2 = 0.054
# Horizon=116: R^2 = 0.047
# Horizon=117: R^2 = 0.038
# Horizon=118: R^2 = 0.033
# Horizon=119: R^2 = 0.026
# Horizon=120: R^2 = 0.023
# Horizon=121: R^2 = 0.018
# Horizon=122: R^2 = 0.019
# Horizon=123: R^2 = 0.020
# Horizon=124: R^2 = 0.019
# Horizon=125: R^2 = 0.022
# Horizon=126: R^2 = 0.024
# Horizon=127: R^2 = 0.031
# Horizon=128: R^2 = 0.033
# Horizon=129: R^2 = 0.041
# Horizon=130: R^2 = 0.048
# Horizon=131: R^2 = 0.054
# Horizon=132: R^2 = 0.062
# Horizon=133: R^2 = 0.065
# Horizon=134: R^2 = 0.073
# Horizon=135: R^2 = 0.082
# Horizon=136: R^2 = 0.085
# Horizon=137: R^2 = 0.099
# Horizon=138: R^2 = 0.103
# Horizon=139: R^2 = 0.109
# Horizon=140: R^2 = 0.111
# Horizon=141: R^2 = 0.121
# Horizon=142: R^2 = 0.125
# Horizon=143: R^2 = 0.130
# Horizon=144: R^2 = 0.135
# Horizon=145: R^2 = 0.136
# Horizon=146: R^2 = 0.144
# Horizon=147: R^2 = 0.142
# Horizon=148: R^2 = 0.143
# Horizon=149: R^2 = 0.138
# Horizon=150: R^2 = 0.138
# Horizon=151: R^2 = 0.134
# Horizon=152: R^2 = 0.137
# Horizon=153: R^2 = 0.126
# Horizon=154: R^2 = 0.121
# Horizon=155: R^2 = 0.114
# Horizon=156: R^2 = 0.110
# Horizon=157: R^2 = 0.100
# Horizon=158: R^2 = 0.094
# Horizon=159: R^2 = 0.086
# Horizon=160: R^2 = 0.081
# Horizon=161: R^2 = 0.071
# Horizon=162: R^2 = 0.067
# Horizon=163: R^2 = 0.061
# Horizon=164: R^2 = 0.057
# Horizon=165: R^2 = 0.052
# Horizon=166: R^2 = 0.049
# Horizon=167: R^2 = 0.046
# Horizon=168: R^2 = 0.045
# Horizon=169: R^2 = 0.046
# Horizon=170: R^2 = 0.045
# Horizon=171: R^2 = 0.048
# Horizon=172: R^2 = 0.051
# Horizon=173: R^2 = 0.055
# Horizon=174: R^2 = 0.062
# Horizon=175: R^2 = 0.068
# Horizon=176: R^2 = 0.074
# Horizon=177: R^2 = 0.086
# Horizon=178: R^2 = 0.096
# Horizon=179: R^2 = 0.104
# Horizon=180: R^2 = 0.117
# Horizon=181: R^2 = 0.131
# Horizon=182: R^2 = 0.142
# Horizon=183: R^2 = 0.151
# Horizon=184: R^2 = 0.163
# Horizon=185: R^2 = 0.174
# Horizon=186: R^2 = 0.182
# Horizon=187: R^2 = 0.191
# Horizon=188: R^2 = 0.197
# Horizon=189: R^2 = 0.200
# Horizon=190: R^2 = 0.204
# Horizon=191: R^2 = 0.211

# %% [markdown]
# ## xgboost classifier model training

# %%
models_bin = {}

precision_scores = {}
recall_scores = {}
accuracy_scores = {}

for horizon in forecast_horizons:
    # create supervised dataset for horizon
    X, y = create_supervised_data(df_aug, horizon=horizon, binary=True)

    # split data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)  

    # train  model
    model_bin = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.1, scale_pos_weight = 50, random_state=42)
    model_bin.fit(X_train, y_train)

    # evaluate model
    y_pred = model_bin.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    accuracy_scores[horizon]=acc
    precision_scores[horizon]=prec
    recall_scores[horizon]=rec
    print(f"Horizon={horizon}: precision = {prec:.3f}, recall = {rec:.3f}")
    
    # save model
    models_bin[horizon] = model_bin
# Out:
# Horizon=1: precision = 0.534, recall = 0.917
# Horizon=2: precision = 0.433, recall = 0.882
# Horizon=3: precision = 0.385, recall = 0.864
# Horizon=4: precision = 0.315, recall = 0.793
# Horizon=5: precision = 0.234, recall = 0.728
# Horizon=6: precision = 0.225, recall = 0.728
# Horizon=7: precision = 0.199, recall = 0.663
# Horizon=8: precision = 0.179, recall = 0.592
# Horizon=9: precision = 0.174, recall = 0.627
# Horizon=10: precision = 0.152, recall = 0.580
# Horizon=11: precision = 0.140, recall = 0.568
# Horizon=12: precision = 0.131, recall = 0.550
# Horizon=13: precision = 0.114, recall = 0.485
# Horizon=14: precision = 0.102, recall = 0.450
# Horizon=15: precision = 0.086, recall = 0.391
# Horizon=16: precision = 0.063, recall = 0.302
# Horizon=17: precision = 0.071, recall = 0.337
# Horizon=18: precision = 0.063, recall = 0.266
# Horizon=19: precision = 0.055, recall = 0.225
# Horizon=20: precision = 0.065, recall = 0.254
# Horizon=21: precision = 0.056, recall = 0.166
# Horizon=22: precision = 0.035, recall = 0.089
# Horizon=23: precision = 0.061, recall = 0.136
# Horizon=24: precision = 0.041, recall = 0.083
# Horizon=25: precision = 0.030, recall = 0.053
# Horizon=26: precision = 0.029, recall = 0.041
# Horizon=27: precision = 0.032, recall = 0.041
# Horizon=28: precision = 0.059, recall = 0.071
# Horizon=29: precision = 0.066, recall = 0.089
# Horizon=30: precision = 0.065, recall = 0.083
# Horizon=31: precision = 0.097, recall = 0.089
# Horizon=32: precision = 0.063, recall = 0.077
# Horizon=33: precision = 0.077, recall = 0.089
# Horizon=34: precision = 0.074, recall = 0.065
# Horizon=35: precision = 0.087, recall = 0.089
# Horizon=36: precision = 0.073, recall = 0.083
# Horizon=37: precision = 0.091, recall = 0.083
# Horizon=38: precision = 0.118, recall = 0.107
# Horizon=39: precision = 0.069, recall = 0.077
# Horizon=40: precision = 0.059, recall = 0.065
# Horizon=41: precision = 0.073, recall = 0.077
# Horizon=42: precision = 0.057, recall = 0.065
# Horizon=43: precision = 0.037, recall = 0.047
# Horizon=44: precision = 0.080, recall = 0.107
# Horizon=45: precision = 0.086, recall = 0.101
# Horizon=46: precision = 0.084, recall = 0.095
# Horizon=47: precision = 0.084, recall = 0.107
# Horizon=48: precision = 0.086, recall = 0.124
# Horizon=49: precision = 0.078, recall = 0.112
# Horizon=50: precision = 0.074, recall = 0.112
# Horizon=51: precision = 0.064, recall = 0.107
# Horizon=52: precision = 0.058, recall = 0.112
# Horizon=53: precision = 0.057, recall = 0.101
# Horizon=54: precision = 0.071, recall = 0.136
# Horizon=55: precision = 0.071, recall = 0.118
# Horizon=56: precision = 0.068, recall = 0.136
# Horizon=57: precision = 0.072, recall = 0.148
# Horizon=58: precision = 0.064, recall = 0.142
# Horizon=59: precision = 0.052, recall = 0.124
# Horizon=60: precision = 0.046, recall = 0.101
# Horizon=61: precision = 0.056, recall = 0.124
# Horizon=62: precision = 0.047, recall = 0.124
# Horizon=63: precision = 0.031, recall = 0.077
# Horizon=64: precision = 0.040, recall = 0.101
# Horizon=65: precision = 0.032, recall = 0.095
# Horizon=66: precision = 0.032, recall = 0.089
# Horizon=67: precision = 0.033, recall = 0.065
# Horizon=68: precision = 0.019, recall = 0.036
# Horizon=69: precision = 0.017, recall = 0.036
# Horizon=70: precision = 0.010, recall = 0.018
# Horizon=71: precision = 0.016, recall = 0.024
# Horizon=72: precision = 0.008, recall = 0.012
# Horizon=73: precision = 0.016, recall = 0.024
# Horizon=74: precision = 0.013, recall = 0.024
# Horizon=75: precision = 0.031, recall = 0.059
# Horizon=76: precision = 0.040, recall = 0.083
# Horizon=77: precision = 0.041, recall = 0.083
# Horizon=78: precision = 0.045, recall = 0.112
# Horizon=79: precision = 0.048, recall = 0.124
# Horizon=80: precision = 0.052, recall = 0.166
# Horizon=81: precision = 0.041, recall = 0.148
# Horizon=82: precision = 0.040, recall = 0.148
# Horizon=83: precision = 0.035, recall = 0.142
# Horizon=84: precision = 0.032, recall = 0.136
# Horizon=85: precision = 0.027, recall = 0.136
# Horizon=86: precision = 0.027, recall = 0.142
# Horizon=87: precision = 0.035, recall = 0.166
# Horizon=88: precision = 0.023, recall = 0.124
# Horizon=89: precision = 0.032, recall = 0.160
# Horizon=90: precision = 0.037, recall = 0.172
# Horizon=91: precision = 0.022, recall = 0.124
# Horizon=92: precision = 0.029, recall = 0.148
# Horizon=93: precision = 0.029, recall = 0.148
# Horizon=94: precision = 0.033, recall = 0.166
# Horizon=95: precision = 0.030, recall = 0.166
# Horizon=96: precision = 0.033, recall = 0.183
# Horizon=97: precision = 0.041, recall = 0.237
# Horizon=98: precision = 0.031, recall = 0.172
# Horizon=99: precision = 0.041, recall = 0.237
# Horizon=100: precision = 0.044, recall = 0.254
# Horizon=101: precision = 0.041, recall = 0.213
# Horizon=102: precision = 0.044, recall = 0.219
# Horizon=103: precision = 0.034, recall = 0.166
# Horizon=104: precision = 0.034, recall = 0.142
# Horizon=105: precision = 0.031, recall = 0.118
# Horizon=106: precision = 0.034, recall = 0.124
# Horizon=107: precision = 0.036, recall = 0.136
# Horizon=108: precision = 0.036, recall = 0.142
# Horizon=109: precision = 0.025, recall = 0.089
# Horizon=110: precision = 0.026, recall = 0.101
# Horizon=111: precision = 0.039, recall = 0.112
# Horizon=112: precision = 0.030, recall = 0.101
# Horizon=113: precision = 0.021, recall = 0.053
# Horizon=114: precision = 0.042, recall = 0.112
# Horizon=115: precision = 0.018, recall = 0.041
# Horizon=116: precision = 0.034, recall = 0.077
# Horizon=117: precision = 0.032, recall = 0.071
# Horizon=118: precision = 0.026, recall = 0.047
# Horizon=119: precision = 0.024, recall = 0.047
# Horizon=120: precision = 0.022, recall = 0.041
# Horizon=121: precision = 0.020, recall = 0.030
# Horizon=122: precision = 0.023, recall = 0.036
# Horizon=123: precision = 0.038, recall = 0.065
# Horizon=124: precision = 0.058, recall = 0.101
# Horizon=125: precision = 0.061, recall = 0.112
# Horizon=126: precision = 0.064, recall = 0.107
# Horizon=127: precision = 0.069, recall = 0.118
# Horizon=128: precision = 0.081, recall = 0.107
# Horizon=129: precision = 0.073, recall = 0.107
# Horizon=130: precision = 0.052, recall = 0.065
# Horizon=131: precision = 0.070, recall = 0.101
# Horizon=132: precision = 0.067, recall = 0.089
# Horizon=133: precision = 0.087, recall = 0.136
# Horizon=134: precision = 0.064, recall = 0.107
# Horizon=135: precision = 0.067, recall = 0.095
# Horizon=136: precision = 0.066, recall = 0.095
# Horizon=137: precision = 0.062, recall = 0.124
# Horizon=138: precision = 0.065, recall = 0.136
# Horizon=139: precision = 0.039, recall = 0.089
# Horizon=140: precision = 0.049, recall = 0.124
# Horizon=141: precision = 0.040, recall = 0.107
# Horizon=142: precision = 0.047, recall = 0.112
# Horizon=143: precision = 0.051, recall = 0.107
# Horizon=144: precision = 0.044, recall = 0.095
# Horizon=145: precision = 0.042, recall = 0.095
# Horizon=146: precision = 0.032, recall = 0.089
# Horizon=147: precision = 0.040, recall = 0.095
# Horizon=148: precision = 0.042, recall = 0.107
# Horizon=149: precision = 0.045, recall = 0.124
# Horizon=150: precision = 0.046, recall = 0.118
# Horizon=151: precision = 0.044, recall = 0.112
# Horizon=152: precision = 0.048, recall = 0.118
# Horizon=153: precision = 0.047, recall = 0.112
# Horizon=154: precision = 0.027, recall = 0.071
# Horizon=155: precision = 0.024, recall = 0.065
# Horizon=156: precision = 0.029, recall = 0.083
# Horizon=157: precision = 0.024, recall = 0.065
# Horizon=158: precision = 0.027, recall = 0.077
# Horizon=159: precision = 0.016, recall = 0.047
# Horizon=160: precision = 0.017, recall = 0.053
# Horizon=161: precision = 0.016, recall = 0.053
# Horizon=162: precision = 0.009, recall = 0.030
# Horizon=163: precision = 0.009, recall = 0.030
# Horizon=164: precision = 0.012, recall = 0.036
# Horizon=165: precision = 0.009, recall = 0.030
# Horizon=166: precision = 0.011, recall = 0.030
# Horizon=167: precision = 0.005, recall = 0.012
# Horizon=168: precision = 0.003, recall = 0.006
# Horizon=169: precision = 0.009, recall = 0.024
# Horizon=170: precision = 0.014, recall = 0.036
# Horizon=171: precision = 0.022, recall = 0.047
# Horizon=172: precision = 0.023, recall = 0.065
# Horizon=173: precision = 0.006, recall = 0.018
# Horizon=174: precision = 0.023, recall = 0.065
# Horizon=175: precision = 0.033, recall = 0.118
# Horizon=176: precision = 0.023, recall = 0.071
# Horizon=177: precision = 0.029, recall = 0.095
# Horizon=178: precision = 0.017, recall = 0.059
# Horizon=179: precision = 0.025, recall = 0.095
# Horizon=180: precision = 0.024, recall = 0.083
# Horizon=181: precision = 0.011, recall = 0.036
# Horizon=182: precision = 0.015, recall = 0.053
# Horizon=183: precision = 0.013, recall = 0.053
# Horizon=184: precision = 0.014, recall = 0.059
# Horizon=185: precision = 0.027, recall = 0.118
# Horizon=186: precision = 0.017, recall = 0.077
# Horizon=187: precision = 0.012, recall = 0.059
# Horizon=188: precision = 0.015, recall = 0.071
# Horizon=189: precision = 0.007, recall = 0.036
# Horizon=190: precision = 0.013, recall = 0.065
# Horizon=191: precision = 0.010, recall = 0.053

# %% [markdown]
# ## model predictions

# %%
def multi_horizon_forecast(row_idx, models, forecast_horizons):
    """Generate multi-step forecasts"""

    target_row = df_aug.iloc[[row_idx]].copy() 
    
    predictions = {}
    predictions_bin= {}
        
    for horizon in forecast_horizons:  

        #augment with known future information
        target_row_idx = target_row.index[0]
        future_index= pd.date_range(start=target_row_idx, periods=horizon,freq=freq)[-1]
        target_row_aug=target_row.copy()
        # weekend
        #target_row_aug['is_weekend'] = int(future_index.dayofweek >= 5)
        # fourier features for day-cycle and year-cycle
        #target_row_aug['sin_day'] = np.sin(2 * np.pi * future_index.hour / 24)
        #target_row_aug['cos_day'] = np.cos(2 * np.pi * future_index.hour / 24)
        #target_row_aug['sin_year'] = np.sin(2 * np.pi * future_index.dayofyear / 365)
        #target_row_aug['cos_year'] = np.cos(2 * np.pi * future_index.dayofyear / 365)
        
        # Predict using the horizon-specific regression model
        model = models[horizon]
        y_pred = model.predict(target_row_aug)  
        predictions[horizon] = y_pred[0]

        # Predict using the horizon-specific binary model
        model_bin = models_bin[horizon]
        y_pred = model_bin.predict_proba(target_row_aug)  
        predictions_bin[horizon] = y_pred[:,1][0]
        
    return predictions, predictions_bin

# %%
df_performance = pd.DataFrame({'horizon':list(r2_scores.keys()), 'r2':list(r2_scores.values()), 'mae':list(mae_scores.values()), 'rmse':list(rmse_scores.values()), 'accuracy':list(accuracy_scores.values()),'precision':list(precision_scores.values()), 'recall':list(recall_scores.values())})

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Regression model performance

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_performance, x="horizon", y="r2", label="R²", color="blue")
sns.lineplot(data=df_performance, x="horizon", y="mae", label="MAE", color="green")
sns.lineplot(data=df_performance, x="horizon", y="rmse", label="RMSE", color="red")

plt.title("model performance for XGboost regression")
plt.xlabel("forecast horizon (15-min Steps)")
plt.ylabel("Model performance")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
#plt.savefig('/Users/tristan/Desktop/stedin_casus/figs/modelperformance_regression.pdf')
plt.show()

# %% [markdown]
# ### Classifier model performance

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_performance, x="horizon", y="accuracy", label="accuracy", color="blue")
sns.lineplot(data=df_performance, x="horizon", y="precision", label="Precision", color="green")
sns.lineplot(data=df_performance, x="horizon", y="recall", label="Recall", color="red")

plt.title("model performance for XGboost classification")
plt.xlabel("forecast horizon (15-min Steps)")
plt.ylabel("Model performance")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
#plt.savefig('/Users/tristan/Desktop/stedin_casus/figs/modelperformance_classifier.pdf')
plt.show()

# %% [markdown]
# ### feature importance

# %%
# feature importance

model_horizon=49

fig, ax = plt.subplots(figsize=(10, 8))  
plot_importance(models[model_horizon], ax = ax)
plt.title('feature importance for regression prediction horizon '+str(model_horizon) )
#plt.savefig('/Users/tristan/Desktop/stedin_casus/figs/featimpreg_'+str(model_horizon)+'.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### example prediction

# %%
exceed = np.where(df_aug['transformer_load']>=1)
print(exceed)
# Out:
# (array([  283,   284,   287,   288,   289,   290,   291,   494,  3017,
#         3018,  3019,  3152,  3468,  4704,  4705,  4706,  4711,  4712,
#         4713,  4716,  4887,  4890,  4891,  4892,  4893,  4894,  5194,
#         5195,  9116, 11331, 11332, 11333, 11334, 12103, 12286, 12295,
#        31484, 31487, 31488, 31489, 31490, 31507, 33694, 33696, 33697,
#        33698, 33699, 33700, 33701, 33702, 33703, 33704, 33705, 33706,
#        33707, 33708, 33709, 34955, 34956, 34957, 34958, 35424, 35425,
#        35517, 35524, 35529, 37049, 37058, 37059, 37060, 37061, 37062,
#        37349, 37351, 37352, 39268, 39269, 39270, 39271, 39272, 39273,
#        39274, 39275, 39276, 39277, 39278, 39279, 39280, 39281, 39285,
#        39286, 40032, 40122, 40123, 40124, 40125, 40126, 40127, 40128,
#        40129, 40133, 40134, 40136, 40137, 40138, 40139, 40140, 40141,
#        40230, 40231, 40232, 40233, 40238, 40239, 40240, 40241, 41273,
#        41274, 41275, 45988, 45989, 45990, 45991, 45992, 45993, 45994,
#        45995, 46001, 46002, 52514, 52515, 52516, 55487, 55488, 55489,
#        55490, 55491, 55492, 55493, 55494, 55495, 56262, 56263, 56264,
#        64709, 64710, 64711, 64712, 65956, 65957, 65962, 65963, 65964,
#        66623, 66718, 66719, 66720, 66721, 66722, 66723, 66725, 66726,
#        66727, 66728, 66729, 66730, 66731, 66732, 66733, 68070, 68076,
#        68077, 68078, 68079, 68160, 68161, 68162, 68163, 68164, 68165,
#        68166, 68167, 68168, 68169, 68170, 68171, 68172, 68173, 68174,
#        68175, 68176, 68178, 68260, 68261, 68262, 68263, 68264, 68455,
#        68456, 69120, 69125, 69227, 69229, 69230, 69231, 69232, 69233,
#        69234, 69306, 69309, 69310, 69313, 69314, 69315, 69316, 69317,
#        69319, 69320, 69321, 69322, 69784, 69785, 69786, 69787, 69788,
#        69789, 69790, 69791, 69792, 69793, 69794, 69795, 69796, 69797,
#        69798, 69799, 69800, 69801, 69802, 69803, 69804, 69805, 69806,
#        69807, 69808, 69809, 69810, 69811, 70182, 70183, 70184, 70185,
#        70186, 70187, 70189, 70935, 70936, 70937, 70938, 70939, 70940,
#        70941, 70942, 70949, 70950, 70951, 71337, 71338, 71339, 71340,
#        71341, 71342, 71343, 71344, 71345, 71346, 71347, 71710, 71711,
#        71715, 71717, 71718, 71719, 71720, 71721, 71722, 71723, 71724,
#        71725, 71726, 71727, 71728, 71730, 73923, 73924, 73925, 73926,
#        73927, 73928, 73931, 73932, 73933, 73934, 74686, 74692, 74694,
#        74695, 74797, 74973, 74974, 74975, 74977, 78826, 78827, 78828,
#        78829, 78910, 78911, 78912, 78913, 78914, 78915, 78916, 78917,
#        78918, 78919, 78920, 78921, 78922, 78926, 78927, 78928, 78929,
#        78933, 79099, 79100, 79101, 79102, 79103, 79104, 79105, 79106,
#        79107, 79108, 79109, 79110, 79111, 79112, 79113, 79114, 79115,
#        79116, 79117, 79783, 79784, 79785, 79795, 79796, 79870, 79871,
#        79872, 79873, 79874, 79875, 79876, 79877, 79878, 79879, 80154,
#        80155, 80157, 80158, 80159, 80160, 80161, 80162, 80163, 80164,
#        80165, 80167, 80168, 80169, 80170, 80171, 80172, 80835, 80836,
#        80837, 80839, 80840, 80841, 80842, 80843, 80844, 80845, 80846,
#        80847, 81502, 81503, 81504, 81505, 81508, 81509, 81510, 81511,
#        81512, 81513, 81514, 81515, 81516, 81517, 81690, 81692, 81693,
#        81694, 81700, 81704, 81705, 81706, 81707, 81708, 81709, 81710,
#        81711, 81790, 81791, 81792, 81793, 81794, 81795, 81796, 81797,
#        81798, 81799, 81802, 81803, 81804, 82372, 82373, 82376, 82377,
#        82378, 82379, 82380, 82381, 84487, 84488, 84489, 86396, 86397,
#        86398, 86399, 86406, 86408, 86409, 86497, 86498, 86499, 86500,
#        88140, 88141, 89096, 89470]),)

# %%
row= 41000

preds, preds_bin = multi_horizon_forecast(row, models, forecast_horizons)

trueval={}
for i in forecast_horizons: 
    trueval[i] = df['transformer_load'].iloc[row + i]

# %%
# Convert dictionary to DataFrame
df_pred = pd.DataFrame.from_dict(preds, orient="index", columns=["prediction"])
df_pred.index.name = "horizon"
  # Convert index to column

df_pred['transformer load'] = trueval
df_pred['probability'] = preds_bin

df_pred.reset_index(inplace=True)

start_time = df.iloc[[row]].index[-1]  # Set your actual start time
df_pred["timestamp"] = start_time + pd.to_timedelta(df_pred["horizon"] * 15, unit="m")

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# plot model predictions 
sns.lineplot(data=df_pred, x="timestamp", y="prediction", ax=ax1, marker="o", label="Predicted Load", color="blue")

# plot true values 
sns.lineplot(data=df_pred, x="timestamp", y="transformer load", ax=ax1, marker="x", label="True Load", color="green")

# plot probability
sns.lineplot(data=df_pred, x="timestamp", y="probability", ax=ax1, linestyle="dashed", color="red", label="P(Load > 1)")

# formatting 
ax1.set_xlabel("Time")
ax1.set_ylabel("Load / Probability")
ax1.set_ylim(0, 1.2)
ax1.legend(loc="upper right")

plt.title("Model Predictions from "+str(start_time))
plt.xticks(rotation=45)  # Rotate x-axis labels
plt.grid(True, linestyle="--", alpha=0.7)  # Dashed gridlines for a cleaner look

#plt.savefig('/Users/tristan/Desktop/stedin_casus/figs/predplot_'+str(row)+'.pdf', bbox_inches='tight')
plt.show()

# %%
alert_timestamps = df_pred['timestamp'][df_pred['probability']>=0.5]
print('raise alert for following timestamps')
print(alert_timestamps)
# Out:
# raise alert for following timestamps
# Series([], Name: timestamp, dtype: datetime64[ns, UTC])
